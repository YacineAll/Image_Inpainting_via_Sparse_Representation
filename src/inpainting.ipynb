# %%
import matplotlib.pyplot as plt
from matplotlib.colors import rgb_to_hsv, hsv_to_rgb
from sklearn.linear_model import Lasso

import numpy as np

from inpainting import *

# %load_ext autoreload
# %autoreload 2

# %%
## On ajoute du bruit pour tester l'algorithme
img = read_im('../data-images/test.jpg')
img_original = img.copy()

noise(img, 10)
img_noised = img.copy()

inpainting(img, 9, 5)

plt.subplot(131)
show_im(img_original)
plt.title('Original image')

plt.subplot(132)
show_im(img_noised)
plt.title('Damaged image')

plt.subplot(133)
show_im(img)
plt.title('Restored image')
# Out:
# 100%|██████████| 1565/1565 [00:00<00:00, 2503.70it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Restored image')

# %%
# On supprime un rectangle entier de l'image
img = read_im('../data-images/test.jpg')
img_original = img.copy()

delete_rect(img, 60, 100, 21, 21)
img_noised = img.copy()

inpainting(img, 21, 15)

plt.subplot(131)
show_im(img_original)
plt.title('Original image')

plt.subplot(132)
show_im(img_noised)
plt.title('Damaged image')

plt.subplot(133)
show_im(img)
plt.title('Restored image')
# Out:
# 100%|██████████| 6/6 [00:02<00:00,  2.58it/s]
# Text(0.5, 1.0, 'Restored image')

# %%
from PIL import Image
# from inpainting import *

Lenna = np.asarray(Image.open("/home/melissa/Desktop/yacine/ml/ml-project/data-images/Lenna.jpg"))
test = read_im('../data-images/test.jpg')#np.asarray(Image.open("../data-images/test.jpg"))
output = "/home/melissa/Desktop/yacine/ml/ml-project/output"

img = read_im('../data-images/Lenna.jpg')
img_original = img.copy()

noise(img, 10)
img_noised = img.copy()


inpainting(img, 7, 7)

plt.subplot(131)
show_im(img_original)
plt.title('Original image')

plt.subplot(132)
show_im(img_noised)
plt.title('Damaged image')

plt.subplot(133)
show_im(img)
plt.title('Restored image')
# Out:
# 100%|██████████| 5198/5198 [05:48<00:00, 14.89it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Restored image')

# %%
img = read_im('../data-images/test.jpg')

img_original, img_noised, img = run_bruit(img, 30, patch_size=3, step=1, alpha=1e-4, max_iter=1e8)
# Out:
#   4%|▍         | 1171/30314 [34:52<35:09:26,  4.34s/it]

# %%
# Out:
# 0

# %%
Image.fromarray(np.uint8(get_img(img_noised)))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FF4364545D0>

# %%
Image.fromarray(np.uint8(get_img(img)))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FF436454710>

# %%
i = 8
Image.fromarray(np.uint8(get_img(img_noised))).save(f'{output}/lenna{i}.jpg')
Image.fromarray(np.uint8(get_img(img))).save(f'{output}/lenna{i}_out.jpg')
