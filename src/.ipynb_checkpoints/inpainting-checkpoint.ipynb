# %%
import matplotlib.pyplot as plt
from matplotlib.colors import rgb_to_hsv, hsv_to_rgb
from sklearn.linear_model import Lasso

import numpy as np

from inpainting import *

# %load_ext autoreload
# %autoreload 2

# %%
def read_im(fn):
    img = rgb_to_hsv(plt.imread(fn))/255
    return 2*img - 1

def get_img(img):
    img_copy = img.copy()
    img_copy[img_copy == np.inf] = -1
    img_copy = 255 * (0.5 * img_copy + 0.5)
    img_copy = np.int32(hsv_to_rgb(img_copy))
    return img_copy

def show_im(img):
    img_copy = img.copy()
    img_copy[img_copy == np.inf] = -1
    img_copy = 255 * (0.5 * img_copy + 0.5)
    img_copy = np.int32(hsv_to_rgb(img_copy))
    plt.imshow(img_copy)

# %%
def patch_to_vect(patch):
    h = patch[:,:, 0].flatten()
    s = patch[:,:, 1].flatten()
    v = patch[:,:, 2].flatten()
    return np.concatenate((h, s, v))


def fill_patch(vect, center, img):
    sz = len(vect) // 3
    h = int(np.sqrt(sz))
    patch = np.zeros((h, h, 3))

    patch[:,:,0] = np.reshape(vect[0:sz], (h, h)) 
    patch[:,:,1] = np.reshape(vect[sz:2*sz], (h, h)) 
    patch[:,:,2] = np.reshape(vect[2*sz:3*sz], (h, h)) 
    
    (i, j) = center
    img[i-h//2:i+h//2, j-h//2:j+h//2] = patch


def get_patch(i, j, h, img):
    assert h % 2 == 1, "Please choose an odd height"
    return patch_to_vect(img[i-h//2:i+h//2, j-h//2:j+h//2])

# %%
def noise(img, prc):
    m, n = (img.shape[0], img.shape[1])
    noise = np.random.randint(100, size=(m, n))
    img[noise < prc, 2] = np.inf

def delete_rect(img, i, j, h, w):
    assert h % 2 == 1, "Please choose an odd height"
    assert w % 2 == 1, "Please choose an odd width"
    img[i-h//2:i+h//2, j-w//2:j+w//2, 2] = np.inf

# %%
"""
"""
def build_dict(img, h, step):
    boolean = False
    
    dictionnary = None
    missing_patches = dict()
    
    m, n, d = img.shape
    limits = (h-1)//2
    
    for i in range(limits, m - limits, step):
        for j in range(limits, n - limits, step):
            patch = get_patch(i, j, h, img)
            if np.sum(patch) != np.inf:
                if(boolean):
                    dictionnary = np.vstack((dictionnary,patch))
                else:
                    dictionnary = patch
                    boolean = True
            else:
                missing_patches[(i, j)]  = patch 
               

    return dictionnary.T, missing_patches
    
"""

def build_dict(img, h, step):
    dictionnary = []
    missing_patches = []

    m, n, d = img.shape
    limits = (h-1)//2

    for i in range(limits, m - limits, step):
        for j in range(limits, n - limits, step):
            patch = get_patch(i, j, h, img)
            if np.sum(patch) != np.inf:
                dictionnary.append(patch)
            else:
                missing_patches.append((patch, (i, j)))

    return np.array(dictionnary).T, missing_patches
"""
print()

"""
def inpainting(img, h, step, alpha=1e-4, max_iter=5000000):
    clf = Lasso(alpha=1e-4, max_iter=max_iter)
    X, Z = build_dict(img, h, step)
    assert len(X) > 0, 'Please choose a smaller step'
    
    for z in Z:
        y = z[0]
        center = z[1]
        nonzero = np.argwhere(y != np.inf).flatten()
        clf.fit(X[nonzero], y[nonzero])

        missing = np.argwhere(y == np.inf).flatten()
        y[missing] = clf.predict(X[missing])

        fill_patch(y, center, img)
"""
def inpainting(img, h, step, alpha=1e-4, max_iter=5000000):
    clf = Lasso(alpha=1e-4, max_iter=max_iter)
    X, Z = build_dict(img, h, step)
    assert len(X) > 0, 'Please choose a smaller step'
    
    for z in Z:
        y = Z[z]
        center = z
        nonzero = np.argwhere(y != np.inf).flatten()
        clf.fit(X[nonzero], y[nonzero])

        missing = np.argwhere(y == np.inf).flatten()
        y[missing] = clf.predict(X[missing])

        fill_patch(y, center, img)

# %%
## On ajoute du bruit pour tester l'algorithme
img = read_im('../data-images/test.jpg')
img_original = img.copy()

noise(img, 10)
img_noised = img.copy()

inpainting(img, 9, 5)

plt.subplot(131)
show_im(img_original)
plt.title('Original image')

plt.subplot(132)
show_im(img_noised)
plt.title('Damaged image')

plt.subplot(133)
show_im(img)
plt.title('Restored image')
# Out:
# 100%|██████████| 1565/1565 [00:01<00:00, 1444.12it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Restored image')

# %%
# On supprime un rectangle entier de l'image
img = read_im('../data-images/test.jpg')
img_original = img.copy()

delete_rect(img, 60, 100, 21, 21)
img_noised = img.copy()

inpainting(img, 21, 15)

plt.subplot(131)
show_im(img_original)
plt.title('Original image')

plt.subplot(132)
show_im(img_noised)
plt.title('Damaged image')

plt.subplot(133)
show_im(img)
plt.title('Restored image')
# Out:
# Text(0.5, 1.0, 'Restored image')

# %%
from PIL import Image
# from inpainting import *

Lenna = np.asarray(Image.open("/home/melissa/Desktop/yacine/ml/ml-project/data-images/Lenna.jpg"))
test = read_im('../data-images/test.jpg')#np.asarray(Image.open("../data-images/test.jpg"))
output = "/home/melissa/Desktop/yacine/ml/ml-project/output"

img = read_im('../data-images/Lenna.jpg')
img_original = img.copy()

noise(img, 10)
img_noised = img.copy()


inpainting(img, 7, 7)

plt.subplot(131)
show_im(img_original)
plt.title('Original image')

plt.subplot(132)
show_im(img_noised)
plt.title('Damaged image')

plt.subplot(133)
show_im(img)
plt.title('Restored image')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Restored image')

# %%
img = read_im('../data-images/test.jpg')

img_original, img_noised, img = run_bruit(img, 10, patch_size=9, step=5, alpha=1e-4, max_iter=1e8)
# Out:
#   5%|▌         | 82/1566 [00:19<00:08, 175.66it/s]

# %%
Image.fromarray(np.uint8(get_img(img_noised)))
# Out:
# <PIL.Image.Image image mode=RGB size=164x250 at 0x7FF4367EF710>

# %%
Image.fromarray(np.uint8(get_img(img)))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FF4447F5E90>
