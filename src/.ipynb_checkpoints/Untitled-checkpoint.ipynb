# %%
from sklearn.datasets import load_sample_image


from inpainting import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
flower_image = load_sample_image("flower.jpg")
china_image = load_sample_image("china.jpg")
Lenna = np.asarray(Image.open("/home/melissa/Desktop/yacine/ml/ml-project/data-images/Lenna.png"))

output = "/home/melissa/Desktop/yacine/ml/ml-project/output"
def add_rectangle(pixels,x: int, y: int, height: int, width: int) -> np.ndarray:
    new_img = pixels.copy()
    new_img[x:x + height, y:y + width] =  np.ones((3,)) * -100
    return new_img

# %%
img = change_color(Lenna,"RGB", "HSV")

show_im(change_color(img,"HSV","RGB"))
new_img = add_noise(img,threshold=0.05)
show_im(change_color(new_img,"HSV","RGB"))
new_new_img=add_rectangle(img,0,0,100,100)
show_im(change_color(new_new_img,"HSV","RGB"))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from inpainting import *
obj = Inpainting(new_img,patch_size=9)
obj.inpaint()
# Out:
# 13024it [13:32, 16.03it/s]
# Donnees d'entrainement recolté...
# Model 1 entrainé...
# Model 2 entrainé...
# Model 3 entrainé...
# Les models sont entranés...
# Predictions...
# /home/melissa/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33706880.0, tolerance: 23645.28515625
#   positive)

# %%
out = obj.predictions()

# %%
show_im(change_color(out,"HSV","RGB"))

# %%
Image.fromarray(np.uint8(change_color(new_img,"HSV","RGB")))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFD6B2CD2D0>

# %%
Image.fromarray(np.uint8(change_color(out,"HSV","RGB")))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFD746E5910>
