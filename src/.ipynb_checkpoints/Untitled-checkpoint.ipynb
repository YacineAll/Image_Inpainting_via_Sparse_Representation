# %%
from sklearn.datasets import load_sample_image


from inpainting import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
flower_image = load_sample_image("flower.jpg")
china_image = load_sample_image("china.jpg")
Lenna = np.asarray(Image.open("/home/melissa/Desktop/yacine/ml/ml-project/data-images/Lenna.png"))

output = "/home/melissa/Desktop/yacine/ml/ml-project/output"
def add_rectangle(pixels,x: int, y: int, height: int, width: int) -> np.ndarray:
    new_img = pixels.copy()
    new_img[x:x + height, y:y + width] =  np.ones((3,)) * -100
    return new_img

# %%
img = change_color(Lenna,"RGB", "HSV")

show_im(change_color(img,"HSV","RGB"))
new_img = add_noise(img,threshold=0.20)
show_im(change_color(new_img,"HSV","RGB"))
new_new_img=add_rectangle(img,0,0,100,100)
show_im(change_color(new_new_img,"HSV","RGB"))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from inpainting import *
obj = Inpainting(new_img,patch_size=3)
out = obj.inp()
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-132-15dfd971b433> in <module>
#       1 from inpainting import *
#       2 obj = Inpainting(new_img,patch_size=3)
# ----> 3 out = obj.inp()
#
# ~/Desktop/yacine/ml/ml-project/src/inpainting.py in inp(self)
#     320                 next_pixel_value = self.predict(x - i + (self.patch_size // 2),
#     321                                                 y - j +
# --> 322                                                 (self.patch_size // 2))
#     323                 out[x, y] = next_pixel_value
#     324         return out
#
# ~/Desktop/yacine/ml/ml-project/src/inpainting.py in predict(self, x, y)
#     231     def predict(self, x, y):
#     232         H = self.classifier_H.predict(
# --> 233             self.dictionary[:, x, y, 0].reshape(1, -1))
#     234         S = self.classifier_S.predict(
#     235             self.dictionary[:, x, y, 1].reshape(1, -1))
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
#     787             The predicted decision function
#     788         """
# --> 789         check_is_fitted(self)
#     790         if sparse.isspmatrix(X):
#     791             return safe_sparse_dot(X, self.coef_.T,
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
#     966     if not attrs:
# --> 967         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     968
#     969
#
# NotFittedError: This Lasso instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
out = obj.predictions()
i = 3
Image.fromarray(np.uint8(change_color(new_img,"HSV","RGB"))).save(f'{output}/lenna{i}.jpg')
Image.fromarray(np.uint8(change_color(out,"HSV","RGB"))).save(f'{output}/lenna{i}_out.jpg')

# %%
show_im(change_color(new_img,"HSV","RGB"))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show_im(change_color(out,"HSV","RGB"))
